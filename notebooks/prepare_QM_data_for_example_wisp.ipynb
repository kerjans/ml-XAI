# %% [markdown]
# # With this Code the data for the examples_wisp.ipynb was prepared.

# %% [markdown]
# Dataset used in the example notebooks:
# ***https://www.kaggle.com/datasets/shivanshuman/quantum-machine-8-aka-qm8***
#
# Source:
# ***https://arxiv.org/abs/1703.00564***

# %%
from rdkit import Chem

import pandas as pd

import os
import re
import pickle

from ase.io import read

import numpy as np

from WISP.ml_helper import get_features

from openbabel import pybel
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import WhiteKernel, RBF, Matern, RationalQuadratic

from dscribe.descriptors import MBTR

from openbabel import openbabel
openbabel.obErrorLog.SetOutputLevel(3)

# %% [markdown]
# ### Functions that will be used to generate .xyz files and split up the original QM8 dataset.

# %%
def gen_xyz_pybel(df, name_col, smiles_col,  out_dir):
    """
    Generates .xyz-files from Smiles-Strings and saves them to a specified diectory.

    Parameters:
        df (pandas.Dataframe): Dataframe containing the Smiles-Strings and the column for naming the .xyz-file.
        name_col (str): Name of the column containing the names that should be used for the .xyz-files.
        smiles_col (str): Name of the Column containing the Smiles-Strings.
        out_dir (str): Path to the directory where the .xyz-files will be saved.
    """

    idx_failed = []
    for idx, row in df.iterrows():
        smiles = row[smiles_col]
        print(f'Converting Smiles: {smiles}')
        name = row[name_col]

        mol = pybel.readstring("smi", smiles)
        mol.addh()
        try:
            print('Starting conversion')
            mol.make3D(forcefield="uff")
            # if more optimization steps are necessary
            #mol.localopt(forcefield='uff')
            xyz_name = f'{name}.xyz'
            save_xyz(mol, xyz_name, out_dir)
            print(f'Conversion for Smiles {smiles} finished')
        except Exception as e:
            print(f"make3D() failed for SMILES={smiles!r} (idx: {idx}): {e}")
            idx_failed.append(idx)

    print('Completed the conversion to .xyz-files.')
    print(f'Indices of molecules with failed conversion:\n{idx_failed}')


def save_xyz(inp_mol, name_col, output_path):
    """
    Saves the embeded and FF-optimized molecule objects to a .xyz-file.

    Parameters:
        inp_mol (pybel.Molecule): pybel.Molecule (wrapper for openbabel.OBMol) objekt to be converted to a .xyz-file
        name_col (str): Name of the .xyz-file. Idealy something that can be matched later to a row in a dataframe.
        output_path (str): Path where the new .xyz-file should be saved.
    """

    filename = name_col
    out_path = os.path.join(output_path, filename)
    inp_mol.write("xyz", out_path)


def gen_clean_name(df, raw_col_name, clean_col_name):
    """
    Replaces the special characters for every string inside raw_col_name and saves the cleaned string in new_col_name.

    Parameters:
        df (pandas.Dataframe): Dataframe containing the raw_col_name column.
        raw_col_name (str): Name of the column containing the raw names with special characters.
        clean_col_name (str): Name of the column for saving the newly generated names. 
    
    Returns:
        df (pandas.Dataframe): Dataframe with the new column containing the cleaned names
    """

    for idx, row in df.iterrows():
        rawname = row[raw_col_name]
        s = rawname.strip().lower()
        s = re.sub(r'[^0-9a-z]+', '_', s)
        s = re.sub(r'_+', '_', s).strip('_')
        new_name = s

        # Save new name in new column
        df.loc[idx, clean_col_name] = new_name
    return df

# %% [markdown]
# #### In the following cell a subset of the QM8 dataset is created, to limit the computing time.
#
# Therefore only 12.5% of the original QM8 dataset is retained using the *sample* methode from pandas (`random_state=42` is used to make the sampling reproducible).
# Afterwards an identifier column is created to name the .xyz files that will be created later in this notebook.

# %%
# Import the dataset
df = pd.read_csv('./data_files/qm8.csv')

# Only retain 12.5% of the original qm8 dataset (reproducible with `random_state=42``)
df_sampled = df.sample(frac=0.125, random_state=42)
df_id_col = df_sampled.copy()

# incorporates an identifier column based on the row indices 
for idx, row in df_id_col.iterrows():
    name = f"{idx}"
    df_id_col.loc[idx, 'mol_id'] = name

# saves the subset to a .csv file
df_id_col.to_csv('./data_files/qm8_subset.csv')

# shows the dataframe after modifications
df_id_col
# Out:
#                                                   smiles    E1-CC2    E2-CC2  \
# 19900  [H]C1([H])C2([H])C([H])([H])C3([H])C4([H])C1([...  0.268963  0.270580
# 19467  [H]C([H])([H])C1([H])OC2([H])C3([H])C([H])([H]...  0.254242  0.262824
# 13787  [H]OC([H])(C([H])([H])[H])C12OC1([H])C([H])([H...  0.266831  0.280019
# 8094           [H]OC1([H])C([H])([H])C12OC(=O)C2([H])[H]  0.227932  0.270654
# 17960         [H]C1=C2C([H])([H])OC2([H])C(=O)C1([H])[H]  0.157602  0.201839
# ...                                                  ...       ...       ...
# 3268     [H]OC([H])([H])C1([H])OC2([H])C([H])([H])C12[H]  0.255623  0.275348
# 11799  [H]C([H])([H])C1(C2(C([H])([H])[H])C([H])([H])...  0.288495  0.293907
# 10904              [H]C(=O)C1([H])OC(=O)N([H])C1([H])[H]  0.159391  0.245802
# 11474  [H]C([H])([H])C([H])([H])C12OC([H])([H])C([H])...  0.257015  0.266735
# 7168   [H][N+]([H])=C(C(=O)[O-])N(C([H])([H])[H])C([H...  0.160415  0.173702
#
#              f1-CC2    f2-CC2   E1-PBE0   E2-PBE0   f1-PBE0   f2-PBE0  \
# 19900  8.294710e-03  0.005270  0.278046  0.293753  0.003283  0.007678
# 19467  9.326290e-03  0.008601  0.271510  0.277585  0.002396  0.001899
# 13787  1.391910e-03  0.025544  0.278261  0.288864  0.000343  0.013774
# 8094   5.977400e-04  0.092588  0.220892  0.263470  0.001079  0.038702
# 17960  1.945700e-04  0.020764  0.152441  0.198269  0.000251  0.001670
# ...             ...       ...       ...       ...       ...       ...
# 3268   4.305030e-03  0.013750  0.268542  0.285748  0.001410  0.010069
# 11799  1.383104e-02  0.001494  0.304986  0.305876  0.002014  0.004446
# 10904  3.090000e-05  0.002251  0.154084  0.202687  0.000032  0.002005
# 11474  3.009810e-03  0.000772  0.272807  0.287922  0.000796  0.000402
# 7168   7.500000e-07  0.000154  0.152038  0.165624  0.000131  0.000422
#
#        E1-PBE0.1  E2-PBE0.1  f1-PBE0.1  f2-PBE0.1    E1-CAM    E2-CAM  f1-CAM  \
# 19900   0.278046   0.293753   0.003283   0.007678  0.272772  0.276531  0.0051
# 19467   0.271510   0.277585   0.002396   0.001899  0.266907  0.268965  0.0099
# 13787   0.278261   0.288864   0.000343   0.013774  0.272970  0.285781  0.0048
# 8094    0.220892   0.263470   0.001079   0.038702  0.220059  0.271188  0.0006
# 17960   0.152441   0.198269   0.000251   0.001670  0.154726  0.212878  0.0001
# ...          ...        ...        ...        ...       ...       ...     ...
# 3268    0.268542   0.285748   0.001410   0.010069  0.262291  0.278538  0.0041
# 11799   0.304986   0.305876   0.002014   0.004446  0.297206  0.299797  0.0055
# 10904   0.154084   0.202687   0.000032   0.002005  0.154432  0.231818  0.0000
# 11474   0.272807   0.287922   0.000796   0.000402  0.270979  0.282000  0.0013
# 7168    0.152038   0.165624   0.000131   0.000422  0.167621  0.179928  0.0000
#
#        f2-CAM mol_id
# 19900  0.0066  19900
# 19467  0.0034  19467
# 13787  0.0127  13787
# 8094   0.0010   8094
# 17960  0.0061  17960
# ...       ...    ...
# 3268   0.0100   3268
# 11799  0.0093  11799
# 10904  0.0021  10904
# 11474  0.0002  11474
# 7168   0.0001   7168
#
# [2723 rows x 18 columns]

# %% [markdown]
# #### Generating the .xyz files from the SMILES-strings using the `gen_xyz_pybel` function.

# %%
df_xyz_conv = pd.read_csv('./data_files/qm8_subset.csv')

gen_xyz_pybel(df_xyz_conv, 'mol_id', 'smiles', './data_files/subset_xyz_qm8/')
# Out:
# Converting Smiles: [H]C1([H])C2([H])C([H])([H])C3([H])C4([H])C1([H])C2([H])C34[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])C2([H])C([H])([H])C3([H])C4([H])C1([H])C2([H])C34[H] finished
# Converting Smiles: [H]C([H])([H])C1([H])OC2([H])C3([H])C([H])([H])C3([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1([H])OC2([H])C3([H])C([H])([H])C3([H])C12[H] finished
# Converting Smiles: [H]OC([H])(C([H])([H])[H])C12OC1([H])C([H])([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])(C([H])([H])[H])C12OC1([H])C([H])([H])C2([H])[H] finished
# Converting Smiles: [H]OC1([H])C([H])([H])C12OC(=O)C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])([H])C12OC(=O)C2([H])[H] finished
# Converting Smiles: [H]C1=C2C([H])([H])OC2([H])C(=O)C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C2C([H])([H])OC2([H])C(=O)C1([H])[H] finished
# Converting Smiles: [H]OC1([H])C([H])([H])C([H])([H])C2(C([H])([H])[H])N([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])([H])C([H])([H])C2(C([H])([H])[H])N([H])C12[H] finished
# Converting Smiles: [H]C(=O)C12C([H])([H])C3([H])C1([H])OC32[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C12C([H])([H])C3([H])C1([H])OC32[H] finished
# Converting Smiles: [H]N([H])C1=NC([H])([H])C([H])([H])N([H])C1=O
# Starting conversion
# Conversion for Smiles [H]N([H])C1=NC([H])([H])C([H])([H])N([H])C1=O finished
# Converting Smiles: [H]OC([H])([H])C1(C([H])([H])C([H])([H])[H])N([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1(C([H])([H])C([H])([H])[H])N([H])C1([H])[H] finished
# Converting Smiles: [H]C(=NC([H])(C([H])([H])[H])C([H])([H])C([H])([H])[H])OC([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=NC([H])(C([H])([H])[H])C([H])([H])C([H])([H])[H])OC([H])([H])[H] finished
# Converting Smiles: [H]C1=C(C([H])([H])[H])C([H])([H])C2(OC2([H])[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C(C([H])([H])[H])C([H])([H])C2(OC2([H])[H])C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])C12C([H])([H])C3([H])OC1([H])C2([H])C3([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C12C([H])([H])C3([H])OC1([H])C2([H])C3([H])[H] finished
# Converting Smiles: [H]C([H])([H])N1C([H])([H])C1([H])C([H])(C([H])([H])[H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])N1C([H])([H])C1([H])C([H])(C([H])([H])[H])C([H])([H])[H] finished
# Converting Smiles: [H]C(=O)C1([H])OC1([H])C1([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C1([H])OC1([H])C1([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])C([H])([H])C(=O)C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C([H])([H])C(=O)C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H] finished
# Converting Smiles: [H]OC1(C#N)C([H])([H])C1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1(C#N)C([H])([H])C1([H])C([H])([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C1([H])OC([H])([H])C([H])([H])O1
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1([H])OC([H])([H])C([H])([H])O1 finished
# Converting Smiles: [H]C#CC([H])(N1C([H])([H])C1([H])[H])C([H])([H])O[H]
# Starting conversion
# Conversion for Smiles [H]C#CC([H])(N1C([H])([H])C1([H])[H])C([H])([H])O[H] finished
# Converting Smiles: [H]N1C(=O)C([H])([H])C([H])([H])C(=O)C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]N1C(=O)C([H])([H])C([H])([H])C(=O)C1([H])[H] finished
# Converting Smiles: [H]N([H])C12C(=O)OC1([H])C([H])([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]N([H])C12C(=O)OC1([H])C([H])([H])C2([H])[H] finished
# Converting Smiles: [H]C(=O)C(=O)N([H])C([H])=NC([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C(=O)N([H])C([H])=NC([H])([H])[H] finished
# Converting Smiles: [H]c1c(C([H])([H])[H])nnc(C([H])([H])[H])c1[H]
# Starting conversion
# Conversion for Smiles [H]c1c(C([H])([H])[H])nnc(C([H])([H])[H])c1[H] finished
# Converting Smiles: [H]N(C([H])([H])C#N)C1([H])C([H])([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]N(C([H])([H])C#N)C1([H])C([H])([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])C1([H])C([H])(C#N)C1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1([H])C([H])(C#N)C1([H])C([H])([H])[H] finished
# Converting Smiles: [H]C(=O)C12N([H])C3([H])C1([H])N([H])C32[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C12N([H])C3([H])C1([H])N([H])C32[H] finished
# Converting Smiles: [H]C([H])([H])C1([H])N2C3([H])C([H])([H])C3([H])C21C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1([H])N2C3([H])C([H])([H])C3([H])C21C([H])([H])[H] finished
# Converting Smiles: [H]C(=O)N([H])C1([H])C([H])([H])C(=O)C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)N([H])C1([H])C([H])([H])C(=O)C1([H])[H] finished
# Converting Smiles: [H]C1([H])OC([H])([H])C2([H])C([H])([H])C([H])([H])C2([H])O1
# Starting conversion
# Conversion for Smiles [H]C1([H])OC([H])([H])C2([H])C([H])([H])C([H])([H])C2([H])O1 finished
# Converting Smiles: [H]C1([H])N(C(=O)C2([H])C([H])([H])C2([H])[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])N(C(=O)C2([H])C([H])([H])C2([H])[H])C1([H])[H] finished
# Converting Smiles: [H]C(=O)C([H])([H])C#CC(=O)N([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C([H])([H])C#CC(=O)N([H])[H] finished
# Converting Smiles: [H]C(=O)C1([H])C([H])([H])C([H])([H])C2([H])C([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C1([H])C([H])([H])C([H])([H])C2([H])C([H])([H])C12[H] finished
# Converting Smiles: [H]C([H])([H])C([H])([H])C([H])([H])C1([H])C([H])([H])C1([H])C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C([H])([H])C([H])([H])C1([H])C([H])([H])C1([H])C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]C([H])([H])C12OC3([H])C4([H])N(C31[H])C42[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C12OC3([H])C4([H])N(C31[H])C42[H] finished
# Converting Smiles: [H]N(C([H])([H])C([H])([H])[H])C([H])(C#N)C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N(C([H])([H])C([H])([H])[H])C([H])(C#N)C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]C([H])([H])C1([H])C2([H])OC([H])([H])C([H])(O2)C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1([H])C2([H])OC([H])([H])C([H])(O2)C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])C([H])([H])C([H])([H])C1([H])C(=O)OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C([H])([H])C([H])([H])C1([H])C(=O)OC1([H])[H] finished
# Converting Smiles: [H]C(=O)C(F)(F)F
# Starting conversion
# Conversion for Smiles [H]C(=O)C(F)(F)F finished
# Converting Smiles: [H]N1C([H])([H])C([H])([H])C([H])(N([H])[H])C1([H])C#N
# Starting conversion
# Conversion for Smiles [H]N1C([H])([H])C([H])([H])C([H])(N([H])[H])C1([H])C#N finished
# Converting Smiles: [H]N=c1nc([H])oc(O[H])c1[H]
# Starting conversion
# Conversion for Smiles [H]N=c1nc([H])oc(O[H])c1[H] finished
# Converting Smiles: [H]OC1([H])C2([H])OC2([H])C12OC2([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C2([H])OC2([H])C12OC2([H])[H] finished
# Converting Smiles: [H]N(C(=O)C([H])([H])C#N)C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N(C(=O)C([H])([H])C#N)C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C([H])(O[H])C([H])(C#N)N([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C([H])(O[H])C([H])(C#N)N([H])[H] finished
# Converting Smiles: [H]C#CC1(O[H])C([H])([H])C1([H])OC([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC1(O[H])C([H])([H])C1([H])OC([H])([H])[H] finished
# Converting Smiles: [H]C#CC1([H])C([H])([H])C([H])([H])C12OC2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC1([H])C([H])([H])C([H])([H])C12OC2([H])[H] finished
# Converting Smiles: [H]OC12C([H])=C([H])C([H])(C([H])([H])[H])C1([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC12C([H])=C([H])C([H])(C([H])([H])[H])C1([H])C2([H])[H] finished
# Converting Smiles: [H]C([H])([H])C#CC([H])([H])C1([H])C([H])([H])OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C#CC([H])([H])C1([H])C([H])([H])OC1([H])[H] finished
# Converting Smiles: [H]c1oc(F)nc(=O)c1[H]
# Starting conversion
# Conversion for Smiles [H]c1oc(F)nc(=O)c1[H] finished
# Converting Smiles: [H]C(=O)N(C(=O)C#N)C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)N(C(=O)C#N)C([H])([H])[H] finished
# Converting Smiles: [H]OC1([H])C(=O)C2([H])N(C([H])([H])[H])C12[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C(=O)C2([H])N(C([H])([H])[H])C12[H] finished
# Converting Smiles: [H]OC([H])([H])c1nc(C([H])([H])[H])n([H])n1
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])c1nc(C([H])([H])[H])n([H])n1 finished
# Converting Smiles: [H]C(=O)C1(C([H])([H])[H])OC([H])([H])OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C1(C([H])([H])[H])OC([H])([H])OC1([H])[H] finished
# Converting Smiles: [H]C(=NC([H])([H])C([H])([H])C#N)OC([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=NC([H])([H])C([H])([H])C#N)OC([H])([H])[H] finished
# Converting Smiles: [H]OC1(C([H])([H])[H])C([H])([H])C1([H])C([H])([H])OC([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1(C([H])([H])[H])C([H])([H])C1([H])C([H])([H])OC([H])([H])[H] finished
# Converting Smiles: [H]OC12C([H])([H])C3([H])C([H])=C([H])C1([H])C32[H]
# Starting conversion
# Conversion for Smiles [H]OC12C([H])([H])C3([H])C([H])=C([H])C1([H])C32[H] finished
# Converting Smiles: [H]OC1(C#N)C([H])([H])C1([H])N([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1(C#N)C([H])([H])C1([H])N([H])[H] finished
# Converting Smiles: [H]C([H])([H])OC([H])([H])C1([H])OC2([H])C([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])OC([H])([H])C1([H])OC2([H])C([H])([H])C12[H] finished
# Converting Smiles: [H]C1=C([H])C2(C([H])([H])[H])C3([H])C([H])([H])C2([H])C13[H]
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C2(C([H])([H])[H])C3([H])C([H])([H])C2([H])C13[H] finished
# Converting Smiles: [H]OC([H])([H])C1=C([H])C([H])([H])C([H])(C([H])([H])[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1=C([H])C([H])([H])C([H])(C([H])([H])[H])C1([H])[H] finished
# Converting Smiles: [H]C(=O)N([H])C([H])([H])C([H])=O
# Starting conversion
# Conversion for Smiles [H]C(=O)N([H])C([H])([H])C([H])=O finished
# Converting Smiles: [H]C(=O)C1([H])C([H])([H])C(=O)N([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C1([H])C([H])([H])C(=O)N([H])C1([H])[H] finished
# Converting Smiles: [H]OC([H])(C([H])=O)C1([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])(C([H])=O)C1([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]C#CC12N([H])C1([H])C([H])=C([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC12N([H])C1([H])C([H])=C([H])C2([H])[H] finished
# Converting Smiles: [H]C1([H])OC(=O)C2(O1)C([H])([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])OC(=O)C2(O1)C([H])([H])C2([H])[H] finished
# Converting Smiles: [H]OC([H])(C([H])([H])[H])C12N(C([H])([H])C1([H])[H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])(C([H])([H])[H])C12N(C([H])([H])C1([H])[H])C2([H])[H] finished
# Converting Smiles: [H]ON=C1C([H])([H])C2([H])C([H])([H])OC12[H]
# Starting conversion
# Conversion for Smiles [H]ON=C1C([H])([H])C2([H])C([H])([H])OC12[H] finished
# Converting Smiles: [H]ON=C1C2([H])OC([H])([H])C1([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]ON=C1C2([H])OC([H])([H])C1([H])C2([H])[H] finished
# Converting Smiles: [H]OC1([H])C(=O)N(C([H])([H])[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C(=O)N(C([H])([H])[H])C1([H])[H] finished
# Converting Smiles: [H]C1=C(C([H])([H])[H])C([H])(C([H])([H])[H])OC1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C(C([H])([H])[H])C([H])(C([H])([H])[H])OC1([H])C([H])([H])[H] finished
# Converting Smiles: [H]N=C1OC([H])([H])C([H])=C1C([H])([H])O[H]
# Starting conversion
# Conversion for Smiles [H]N=C1OC([H])([H])C([H])=C1C([H])([H])O[H] finished
# Converting Smiles: [H]C([H])([H])C([H])([H])OC1([H])C(=O)C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C([H])([H])OC1([H])C(=O)C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]C#CC([H])([H])c1nc([H])no1
# Starting conversion
# Conversion for Smiles [H]C#CC([H])([H])c1nc([H])no1 finished
# Converting Smiles: [H]OC([H])([H])C([H])([H])N1C([H])([H])C1([H])C#N
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C([H])([H])N1C([H])([H])C1([H])C#N finished
# Converting Smiles: [H]N=c1nc([H])c(F)c([H])o1
# Starting conversion
# Conversion for Smiles [H]N=c1nc([H])c(F)c([H])o1 finished
# Converting Smiles: [H]OC1([H])C2([H])N(C2([H])[H])C([H])([H])C1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C2([H])N(C2([H])[H])C([H])([H])C1([H])C([H])([H])[H] finished
# Converting Smiles: [H]N1C([H])([H])C1([H])C(=O)N1C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]N1C([H])([H])C1([H])C(=O)N1C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]C#CC([H])([H])C(OC([H])([H])[H])(C([H])([H])[H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC([H])([H])C(OC([H])([H])[H])(C([H])([H])[H])C([H])([H])[H] finished
# Converting Smiles: [H]c1c(N([H])C([H])([H])[H])c(C([H])([H])[H])c([H])n1[H]
# Starting conversion
# Conversion for Smiles [H]c1c(N([H])C([H])([H])[H])c(C([H])([H])[H])c([H])n1[H] finished
# Converting Smiles: [H]OC([H])([H])C(=NC([H])([H])[H])N([H])C([H])=O
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C(=NC([H])([H])[H])N([H])C([H])=O finished
# Converting Smiles: [H]Oc1c([H])c([H])nn1C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]Oc1c([H])c([H])nn1C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]C1=C([H])C([H])([H])C([H])(OC([H])([H])[H])C1=O
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C([H])([H])C([H])(OC([H])([H])[H])C1=O finished
# Converting Smiles: [H]C([H])([H])C1([H])OC([H])([H])C1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1([H])OC([H])([H])C1([H])C([H])([H])[H] finished
# Converting Smiles: [H]N1C(=O)N([H])C(C([H])([H])[H])(C([H])([H])[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]N1C(=O)N([H])C(C([H])([H])[H])(C([H])([H])[H])C1([H])[H] finished
# Converting Smiles: [H]OC([H])(C([H])([H])[H])C1([H])C([H])([H])C1([H])C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])(C([H])([H])[H])C1([H])C([H])([H])C1([H])C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]c1c(OC([H])([H])[H])nn([H])c1[H]
# Starting conversion
# Conversion for Smiles [H]c1c(OC([H])([H])[H])nn([H])c1[H] finished
# Converting Smiles: [H]N([H])C(=O)C([H])([H])C([H])([H])C1([H])OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]N([H])C(=O)C([H])([H])C([H])([H])C1([H])OC1([H])[H] finished
# Converting Smiles: [H]OC1([H])C([H])([H])C([H])=C([H])C2([H])OC21[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])([H])C([H])=C([H])C2([H])OC21[H] finished
# Converting Smiles: [H]c1nc([H])c(C([H])([H])C([H])([H])[H])c([H])n1
# Starting conversion
# Conversion for Smiles [H]c1nc([H])c(C([H])([H])C([H])([H])[H])c([H])n1 finished
# Converting Smiles: [H]N1C([H])([H])C1([H])C#CC([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N1C([H])([H])C1([H])C#CC([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]N1C([H])([H])C2([H])OC2(C#N)C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]N1C([H])([H])C2([H])OC2(C#N)C1([H])[H] finished
# Converting Smiles: [H]c1c(C([H])([H])[H])c(C([H])([H])[H])c(N([H])[H])n1[H]
# Starting conversion
# Conversion for Smiles [H]c1c(C([H])([H])[H])c(C([H])([H])[H])c(N([H])[H])n1[H] finished
# Converting Smiles: [H]N=C1OC(=O)C([H])=C1[H]
# Starting conversion
# Conversion for Smiles [H]N=C1OC(=O)C([H])=C1[H] finished
# Converting Smiles: [H]C#CC([H])(O[H])C(F)(F)F
# Starting conversion
# Conversion for Smiles [H]C#CC([H])(O[H])C(F)(F)F finished
# Converting Smiles: [H]C#Cc1c([H])c([H])nn1C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#Cc1c([H])c([H])nn1C([H])([H])[H] finished
# Converting Smiles: N#CC#CC#N
# Starting conversion
# Conversion for Smiles N#CC#CC#N finished
# Converting Smiles: [H]Oc1c(C([H])([H])[H])c([H])c([H])n1[H]
# Starting conversion
# Conversion for Smiles [H]Oc1c(C([H])([H])[H])c([H])c([H])n1[H] finished
# Converting Smiles: [H]C1([H])C([H])([H])C1([H])OC1([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])C([H])([H])C1([H])OC1([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]C1([H])C(=O)C([H])([H])N1C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])C(=O)C([H])([H])N1C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]C(=O)C(=O)N([H])C(=O)N([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C(=O)N([H])C(=O)N([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C([H])(C#CC([H])=O)C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C([H])(C#CC([H])=O)C([H])([H])[H] finished
# Converting Smiles: [H]OC12C3=NC([H])([H])C1([H])C2([H])O3
# Starting conversion
# Conversion for Smiles [H]OC12C3=NC([H])([H])C1([H])C2([H])O3 finished
# Converting Smiles: [H]C([H])([H])C#CC([H])([H])C1(C([H])([H])[H])OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C#CC([H])([H])C1(C([H])([H])[H])OC1([H])[H] finished
# Converting Smiles: [H]Oc1nn([H])c([H])c1N([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]Oc1nn([H])c([H])c1N([H])C([H])([H])[H] finished
# Converting Smiles: [H]C(=O)C#CC([H])([H])C1([H])N([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C#CC([H])([H])C1([H])N([H])C1([H])[H] finished
# Converting Smiles: [H]C#CC1(C#N)N([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC1(C#N)N([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C([H])([H])C(=O)C([H])([H])C#N
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C([H])([H])C(=O)C([H])([H])C#N finished
# Converting Smiles: [H]N([H])C(=O)C([H])([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N([H])C(=O)C([H])([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]C1(C#N)OC2([H])C([H])([H])C2([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1(C#N)OC2([H])C([H])([H])C2([H])C1([H])[H] finished
# Converting Smiles: [H]C(=O)N([H])C([H])([H])C([H])([H])C([H])([H])C([H])=O
# Starting conversion
# Conversion for Smiles [H]C(=O)N([H])C([H])([H])C([H])([H])C([H])([H])C([H])=O finished
# Converting Smiles: [H]c1nn2c(c1[H])C([H])([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]c1nn2c(c1[H])C([H])([H])C2([H])[H] finished
# Converting Smiles: [H]N=C1OC([H])(C([H])([H])C([H])([H])C([H])([H])[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]N=C1OC([H])(C([H])([H])C([H])([H])C([H])([H])[H])C1([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C([H])([H])C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C([H])([H])C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H] finished
# Converting Smiles: [H]C1=NC2([H])C([H])(O1)C1([H])OC21[H]
# Starting conversion
# Conversion for Smiles [H]C1=NC2([H])C([H])(O1)C1([H])OC21[H] finished
# Converting Smiles: [H]C#Cc1c([H])nn([H])c1O[H]
# Starting conversion
# Conversion for Smiles [H]C#Cc1c([H])nn([H])c1O[H] finished
# Converting Smiles: [H]N=C1OC([H])(C([H])([H])[H])C2([H])N1C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]N=C1OC([H])(C([H])([H])[H])C2([H])N1C2([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C1([H])C([H])(C([H])([H])[H])C2([H])C([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1([H])C([H])(C([H])([H])[H])C2([H])C([H])([H])C12[H] finished
# Converting Smiles: [H]C1=C([H])C([H])(C#N)C([H])([H])OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C([H])(C#N)C([H])([H])OC1([H])[H] finished
# Converting Smiles: [H]C([H])([H])C#CC([H])(C#N)C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C#CC([H])(C#N)C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]C#CC1=C([H])C([H])(C([H])([H])[H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC1=C([H])C([H])(C([H])([H])[H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]C(=O)c1c([H])nc(C([H])([H])[H])n1[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)c1c([H])nc(C([H])([H])[H])n1[H] finished
# Converting Smiles: [H]C([H])([H])OC1([H])C([H])([H])C([H])([H])C([H])([H])C1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])OC1([H])C([H])([H])C([H])([H])C([H])([H])C1([H])C([H])([H])[H] finished
# Converting Smiles: [H]c1c([H])c(N([H])[H])n([H])c1N([H])[H]
# Starting conversion
# Conversion for Smiles [H]c1c([H])c(N([H])[H])n([H])c1N([H])[H] finished
# Converting Smiles: [H]N=C([H])N([H])c1c([H])noc1[H]
# Starting conversion
# Conversion for Smiles [H]N=C([H])N([H])c1c([H])noc1[H] finished
# Converting Smiles: [H]C#CC([H])([H])C(=O)C([H])=O
# Starting conversion
# Conversion for Smiles [H]C#CC([H])([H])C(=O)C([H])=O finished
# Converting Smiles: [H]OC1([H])C([H])(C([H])([H])[H])C2([H])N([H])C12C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])(C([H])([H])[H])C2([H])N([H])C12C([H])([H])[H] finished
# Converting Smiles: [H]C([H])([H])C12OC3([H])C([H])(C1=O)C32[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C12OC3([H])C([H])(C1=O)C32[H] finished
# Converting Smiles: [H]c1nnn(C([H])(C([H])([H])[H])C([H])([H])[H])c1[H]
# Starting conversion
# Conversion for Smiles [H]c1nnn(C([H])(C([H])([H])[H])C([H])([H])[H])c1[H] finished
# Converting Smiles: [H]N=c1oc(N([H])[H])c([H])c([H])c1[H]
# Starting conversion
# Conversion for Smiles [H]N=c1oc(N([H])[H])c([H])c([H])c1[H] finished
# Converting Smiles: [H]C([H])([H])C1([H])C([H])(C#N)C2([H])OC21[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1([H])C([H])(C#N)C2([H])OC21[H] finished
# Converting Smiles: [H]C#CC1([H])OC([H])(C([H])([H])[H])OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC1([H])OC([H])(C([H])([H])[H])OC1([H])[H] finished
# Converting Smiles: [H]OC1([H])C2(C([H])([H])[H])C([H])([H])C([H])([H])C12C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C2(C([H])([H])[H])C([H])([H])C([H])([H])C12C([H])([H])[H] finished
# Converting Smiles: [H]C([H])([H])C12C3([H])OC1([H])C([H])([H])C2([H])C3([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C12C3([H])OC1([H])C([H])([H])C2([H])C3([H])[H] finished
# Converting Smiles: [H]c1nc(C([H])([H])C#N)n([H])n1
# Starting conversion
# Conversion for Smiles [H]c1nc(C([H])([H])C#N)n([H])n1 finished
# Converting Smiles: [H]c1oc(C([H])([H])[H])c(N([H])[H])c1[H]
# Starting conversion
# Conversion for Smiles [H]c1oc(C([H])([H])[H])c(N([H])[H])c1[H] finished
# Converting Smiles: [H]C#CC([H])([H])C1([H])C([H])([H])C2([H])OC21[H]
# Starting conversion
# Conversion for Smiles [H]C#CC([H])([H])C1([H])C([H])([H])C2([H])OC21[H] finished
# Converting Smiles: [H]C#CC12N([H])C1([H])C([H])([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC12N([H])C1([H])C([H])([H])C2([H])[H] finished
# Converting Smiles: [H]OC([H])(C1([H])N([H])C1([H])[H])C1([H])N([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])(C1([H])N([H])C1([H])[H])C1([H])N([H])C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])C1=NC([H])([H])C2(O1)C([H])([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1=NC([H])([H])C2(O1)C([H])([H])C2([H])[H] finished
# Converting Smiles: [H]N([H])c1c(C([H])([H])[H])noc1C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N([H])c1c(C([H])([H])[H])noc1C([H])([H])[H] finished
# Converting Smiles: [H]c1nc(C(=O)C([H])([H])[H])c([H])o1
# Starting conversion
# Conversion for Smiles [H]c1nc(C(=O)C([H])([H])[H])c([H])o1 finished
# Converting Smiles: [H]C1=C([H])C2([H])C3([H])OC1([H])C32C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C2([H])C3([H])OC1([H])C32C([H])([H])[H] finished
# Converting Smiles: [H]C([H])([H])C1([H])OC2(C([H])([H])C1([H])[H])C([H])([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1([H])OC2(C([H])([H])C1([H])[H])C([H])([H])C2([H])[H] finished
# Converting Smiles: [H]C1([H])C2([H])OC(=O)N3C1([H])C32[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])C2([H])OC(=O)N3C1([H])C32[H] finished
# Converting Smiles: [H]OC([H])([H])C([H])([H])C([H])([H])O[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C([H])([H])C([H])([H])O[H] finished
# Converting Smiles: [H]OC1([H])C([H])(C#N)N([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])(C#N)N([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]N([H])C([H])(C#N)C([H])([H])OC([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N([H])C([H])(C#N)C([H])([H])OC([H])([H])[H] finished
# Converting Smiles: [H]c1c(N([H])[H])noc1N([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]c1c(N([H])[H])noc1N([H])C([H])([H])[H] finished
# Converting Smiles: [H]c1nc2onc([H])c2o1
# Starting conversion
# Conversion for Smiles [H]c1nc2onc([H])c2o1 finished
# Converting Smiles: [H]C([H])([H])C12OC1([H])C1([H])C([H])([H])C([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C12OC1([H])C1([H])C([H])([H])C([H])([H])C12[H] finished
# Converting Smiles: [H]N=C1OC2([H])C([H])([H])OC([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]N=C1OC2([H])C([H])([H])OC([H])([H])C12[H] finished
# Converting Smiles: [H]OC1([H])C([H])([H])N2C([H])(C([H])([H])[H])C2([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])([H])N2C([H])(C([H])([H])[H])C2([H])C1([H])[H] finished
# Converting Smiles: [H]Oc1c([H])oc([H])c1C([H])([H])O[H]
# Starting conversion
# Conversion for Smiles [H]Oc1c([H])oc([H])c1C([H])([H])O[H] finished
# Converting Smiles: [H]C#CC12C([H])([H])N3C([H])([H])C1([H])C32[H]
# Starting conversion
# Conversion for Smiles [H]C#CC12C([H])([H])N3C([H])([H])C1([H])C32[H] finished
# Converting Smiles: [H]OC1(C([H])([H])C([H])=O)C([H])([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1(C([H])([H])C([H])=O)C([H])([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]N=C([H])Oc1nc([H])c([H])o1
# Starting conversion
# Conversion for Smiles [H]N=C([H])Oc1nc([H])c([H])o1 finished
# Converting Smiles: [H]OC([H])([H])C([H])(C([H])([H])[H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C([H])(C([H])([H])[H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]C1([H])OC12C1([H])C([H])([H])C2([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])OC12C1([H])C([H])([H])C2([H])C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])C([H])([H])C12OC(=O)C1([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C([H])([H])C12OC(=O)C1([H])C2([H])[H] finished
# Converting Smiles: [H]C1([H])N2C3([H])C(=O)C2([H])C1([H])C3([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])N2C3([H])C(=O)C2([H])C1([H])C3([H])[H] finished
# Converting Smiles: [H]OC([H])([H])c1nnoc1N([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])c1nnoc1N([H])[H] finished
# Converting Smiles: [H]C1=NC([H])([H])C([H])([H])C([H])=C([H])C([H])([H])O1
# Starting conversion
# Conversion for Smiles [H]C1=NC([H])([H])C([H])([H])C([H])=C([H])C([H])([H])O1 finished
# Converting Smiles: [H]C([H])([H])C12C([H])([H])C([H])([H])C3([H])C([H])(C1([H])[H])C32[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C12C([H])([H])C([H])([H])C3([H])C([H])(C1([H])[H])C32[H] finished
# Converting Smiles: [H]OC([H])(C#CC1([H])N([H])C1([H])[H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])(C#CC1([H])N([H])C1([H])[H])C([H])([H])[H] finished
# Converting Smiles: [H]c1nc2c([H])noc2o1
# Starting conversion
# Conversion for Smiles [H]c1nc2c([H])noc2o1 finished
# Converting Smiles: [H]C([H])([H])OC(C([H])([H])[H])(C([H])([H])[H])C([H])([H])C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])OC(C([H])([H])[H])(C([H])([H])[H])C([H])([H])C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]C([H])([H])C1([H])C2([H])OC([H])(C#N)C21[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1([H])C2([H])OC([H])(C#N)C21[H] finished
# Converting Smiles: [H]C([H])([H])C1([H])OC12C(=O)OC2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1([H])OC12C(=O)OC2([H])[H] finished
# Converting Smiles: [H]Oc1nnc(C([H])([H])[H])nc1[H]
# Starting conversion
# Conversion for Smiles [H]Oc1nnc(C([H])([H])[H])nc1[H] finished
# Converting Smiles: [H]OC([H])([H])C(=O)C1([H])C([H])([H])OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C(=O)C1([H])C([H])([H])OC1([H])[H] finished
# Converting Smiles: [H]c1oc([H])c(C2([H])OC2([H])[H])c1[H]
# Starting conversion
# Conversion for Smiles [H]c1oc([H])c(C2([H])OC2([H])[H])c1[H] finished
# Converting Smiles: [H]C(=O)C(N1C([H])([H])C1([H])[H])(C([H])([H])[H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C(N1C([H])([H])C1([H])[H])(C([H])([H])[H])C([H])([H])[H] finished
# Converting Smiles: [H]C12OC3([H])C1([H])OC23[H]
# Starting conversion
# Conversion for Smiles [H]C12OC3([H])C1([H])OC23[H] finished
# Converting Smiles: [H]C#CC1([H])C([H])([H])C1([H])C([H])([H])C([H])([H])O[H]
# Starting conversion
# Conversion for Smiles [H]C#CC1([H])C([H])([H])C1([H])C([H])([H])C([H])([H])O[H] finished
# Converting Smiles: [H]N1C2([H])C([H])([H])C([H])([H])C1(C#N)C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]N1C2([H])C([H])([H])C([H])([H])C1(C#N)C2([H])[H] finished
# Converting Smiles: [H]C1([H])OC(C([H])([H])[H])(C([H])([H])[H])C([H])([H])C1=O
# Starting conversion
# Conversion for Smiles [H]C1([H])OC(C([H])([H])[H])(C([H])([H])[H])C([H])([H])C1=O finished
# Converting Smiles: [H]OC1([H])C([H])([H])C([H])(C([H])([H])[H])OC1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])([H])C([H])(C([H])([H])[H])OC1([H])C([H])([H])[H] finished
# Converting Smiles: [H]c1nn([H])nc1N([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]c1nn([H])nc1N([H])C([H])([H])[H] finished
# Converting Smiles: [H]Oc1nc(N([H])[H])oc1N([H])[H]
# Starting conversion
# Conversion for Smiles [H]Oc1nc(N([H])[H])oc1N([H])[H] finished
# Converting Smiles: [H]OC1([H])C2([H])C([H])([H])C([H])([H])C([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C2([H])C([H])([H])C([H])([H])C([H])([H])C12[H] finished
# Converting Smiles: [H]C1([H])OC([H])(C#CC#N)C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])OC([H])(C#CC#N)C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])OC1([H])C(=O)C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])OC1([H])C(=O)C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])C12C([H])([H])C([H])([H])OC1([H])C([H])([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C12C([H])([H])C([H])([H])OC1([H])C([H])([H])C2([H])[H] finished
# Converting Smiles: [H]C1([H])OC2([H])C([H])(C#N)C([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])OC2([H])C([H])(C#N)C([H])([H])C12[H] finished
# Converting Smiles: [H]OC1(C([H])([H])C#CC([H])([H])[H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1(C([H])([H])C#CC([H])([H])[H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]C1=C([H])C([H])([H])OC([H])([H])C(C([H])([H])[H])=C1[H]
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C([H])([H])OC([H])([H])C(C([H])([H])[H])=C1[H] finished
# Converting Smiles: [H]OC([H])([H])C1([H])C(=O)C([H])(C([H])([H])[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1([H])C(=O)C([H])(C([H])([H])[H])C1([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C1(O[H])C([H])([H])N(C([H])([H])[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1(O[H])C([H])([H])N(C([H])([H])[H])C1([H])[H] finished
# Converting Smiles: [H]C#CC12C([H])([H])OC1(C([H])([H])[H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC12C([H])([H])OC1(C([H])([H])[H])C2([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C1([H])C([H])([H])C([H])([H])C1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1([H])C([H])([H])C([H])([H])C1([H])C([H])([H])[H] finished
# Converting Smiles: [H]C1=C(N([H])[H])C(=O)C([H])([H])C1=O
# Starting conversion
# Conversion for Smiles [H]C1=C(N([H])[H])C(=O)C([H])([H])C1=O finished
# Converting Smiles: [H]C([H])([H])C1([H])OC2([H])C([H])([H])C2(C([H])([H])[H])O1
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1([H])OC2([H])C([H])([H])C2(C([H])([H])[H])O1 finished
# Converting Smiles: [H]C1=C([H])C2([H])N([H])C2([H])C(=O)C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C2([H])N([H])C2([H])C(=O)C1([H])[H] finished
# Converting Smiles: [H]N1C([H])([H])C(C([H])([H])[H])(C([H])([H])[H])C1([H])C#N
# Starting conversion
# Conversion for Smiles [H]N1C([H])([H])C(C([H])([H])[H])(C([H])([H])[H])C1([H])C#N finished
# Converting Smiles: [H]c1nc(OC([H])([H])[H])nn1C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]c1nc(OC([H])([H])[H])nn1C([H])([H])[H] finished
# Converting Smiles: [H]N=c1oc([H])c(C([H])([H])[H])c([H])c1[H]
# Starting conversion
# Conversion for Smiles [H]N=c1oc([H])c(C([H])([H])[H])c([H])c1[H] finished
# Converting Smiles: [H]C([H])([H])N1C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])N1C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]c1oc([H])c(OC([H])([H])C([H])([H])[H])c1[H]
# Starting conversion
# Conversion for Smiles [H]c1oc([H])c(OC([H])([H])C([H])([H])[H])c1[H] finished
# Converting Smiles: [H]C([H])(C#CC([H])([H])C([H])([H])[H])OC([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])(C#CC([H])([H])C([H])([H])[H])OC([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]N1C2([H])C3([H])C([H])([H])C2([H])C13C#N
# Starting conversion
# Conversion for Smiles [H]N1C2([H])C3([H])C([H])([H])C2([H])C13C#N finished
# Converting Smiles: [H]N=c1c([H])nn([H])c(N([H])[H])c1[H]
# Starting conversion
# Conversion for Smiles [H]N=c1c([H])nn([H])c(N([H])[H])c1[H] finished
# Converting Smiles: [H]OC1([H])C([H])([H])OC12C([H])([H])OC2([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])([H])OC12C([H])([H])OC2([H])[H] finished
# Converting Smiles: [H]OC1([H])C([H])(C#N)C1(N([H])[H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])(C#N)C1(N([H])[H])C([H])([H])[H] finished
# Converting Smiles: [H]C([H])([H])C([H])([H])C1([H])C2([H])C([H])([H])OC21C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C([H])([H])C1([H])C2([H])C([H])([H])OC21C([H])([H])[H] finished
# Converting Smiles: [H]C1=C(C([H])([H])C([H])([H])[H])C2([H])N([H])C2([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C(C([H])([H])C([H])([H])[H])C2([H])N([H])C2([H])C1([H])[H] finished
# Converting Smiles: [H]C1=C([H])C2([H])C([H])([H])C2([H])C1=O
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C2([H])C([H])([H])C2([H])C1=O finished
# Converting Smiles: [H]OC([H])([H])C([H])([H])C1=C([H])C([H])([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C([H])([H])C1=C([H])C([H])([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]c1oc([H])c(C([H])([H])C([H])([H])[H])c1[H]
# Starting conversion
# Conversion for Smiles [H]c1oc([H])c(C([H])([H])C([H])([H])[H])c1[H] finished
# Converting Smiles: [H]C([H])([H])N=C1OC([H])([H])OC([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])N=C1OC([H])([H])OC([H])([H])C1([H])[H] finished
# Converting Smiles: [H]OC1([H])C([H])([H])C([H])=C([H])C1([H])OC([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])([H])C([H])=C([H])C1([H])OC([H])([H])[H] finished
# Converting Smiles: [H]N=C1N([H])C(=O)C([H])([H])C([H])([H])N1[H]
# Starting conversion
# Conversion for Smiles [H]N=C1N([H])C(=O)C([H])([H])C([H])([H])N1[H] finished
# Converting Smiles: [H]C1=C([H])C2([H])OC2([H])C([H])([H])OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C2([H])OC2([H])C([H])([H])OC1([H])[H] finished
# Converting Smiles: [H]C(=O)C1([H])C([H])(C([H])([H])[H])OC1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C1([H])C([H])(C([H])([H])[H])OC1([H])C([H])([H])[H] finished
# Converting Smiles: [H]c1nn(C([H])([H])[H])c([H])c1OC([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]c1nn(C([H])([H])[H])c([H])c1OC([H])([H])[H] finished
# Converting Smiles: [H]N([H])C(=O)C1(C([H])([H])[H])OC1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N([H])C(=O)C1(C([H])([H])[H])OC1([H])C([H])([H])[H] finished
# Converting Smiles: [H]C1=C2C([H])([H])C([H])([H])C2([H])OC1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C2C([H])([H])C([H])([H])C2([H])OC1([H])C([H])([H])[H] finished
# Converting Smiles: [H]OC1(C([H])([H])[H])C([H])([H])C1([H])N1C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1(C([H])([H])[H])C([H])([H])C1([H])N1C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]OC([H])(C([H])([H])C([H])([H])C([H])([H])[H])C1([H])N([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])(C([H])([H])C([H])([H])C([H])([H])[H])C1([H])N([H])C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])C([H])(C#N)OC1([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C([H])(C#N)OC1([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]N=C(C([H])=O)N([H])C([H])([H])C([H])([H])O[H]
# Starting conversion
# Conversion for Smiles [H]N=C(C([H])=O)N([H])C([H])([H])C([H])([H])O[H] finished
# Converting Smiles: [H]c1c([H])n([H])c2c([H])nn([H])c12
# Starting conversion
# Conversion for Smiles [H]c1c([H])n([H])c2c([H])nn([H])c12 finished
# Converting Smiles: [H]C([H])([H])C12OC([H])([H])C3([H])C([H])(C1([H])[H])C32[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C12OC([H])([H])C3([H])C([H])(C1([H])[H])C32[H] finished
# Converting Smiles: [H]c1onc(C([H])([H])[H])c1OC([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]c1onc(C([H])([H])[H])c1OC([H])([H])[H] finished
# Converting Smiles: [H]C1([H])C(=O)C2(C([H])([H])C1([H])[H])C([H])([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])C(=O)C2(C([H])([H])C1([H])[H])C([H])([H])C2([H])[H] finished
# Converting Smiles: [H]C([H])([H])C([H])([H])C1([H])C2([H])C(=O)C1([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C([H])([H])C1([H])C2([H])C(=O)C1([H])C2([H])[H] finished
# Converting Smiles: [H]C#CC([H])([H])C1([H])N([H])C1([H])C([H])([H])O[H]
# Starting conversion
# Conversion for Smiles [H]C#CC([H])([H])C1([H])N([H])C1([H])C([H])([H])O[H] finished
# Converting Smiles: [H]N1C2([H])C(=O)C(=O)C1([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]N1C2([H])C(=O)C(=O)C1([H])C2([H])[H] finished
# Converting Smiles: [H]c1nn([H])c2c([H])nn([H])c12
# Starting conversion
# Conversion for Smiles [H]c1nn([H])c2c([H])nn([H])c12 finished
# Converting Smiles: [H]OC1([H])C(=O)C([H])([H])C(C([H])([H])[H])=C1[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C(=O)C([H])([H])C(C([H])([H])[H])=C1[H] finished
# Converting Smiles: [H]OC([H])(C#CC([H])([H])[H])C1([H])N([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])(C#CC([H])([H])[H])C1([H])N([H])C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])C([H])([H])C12OC3([H])C([H])([H])C1([H])C32[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C([H])([H])C12OC3([H])C([H])([H])C1([H])C32[H] finished
# Converting Smiles: [H]OC([H])([H])C1(O[H])C2([H])N([H])C1([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1(O[H])C2([H])N([H])C1([H])C2([H])[H] finished
# Converting Smiles: [H]C#CC12N(C1([H])[H])C([H])(C([H])([H])[H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC12N(C1([H])[H])C([H])(C([H])([H])[H])C2([H])[H] finished
# Converting Smiles: [H]C1([H])OC2([H])C1([H])OC1([H])C([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])OC2([H])C1([H])OC1([H])C([H])([H])C12[H] finished
# Converting Smiles: [H]C([H])([H])C12OC([H])(C([H])([H])OC1([H])[H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C12OC([H])(C([H])([H])OC1([H])[H])C2([H])[H] finished
# Converting Smiles: [H]c1c([H])c([H])c(C([H])([H])[H])c(C([H])([H])[H])c1[H]
# Starting conversion
# Conversion for Smiles [H]c1c([H])c([H])c(C([H])([H])[H])c(C([H])([H])[H])c1[H] finished
# Converting Smiles: [H]N=c1nc([H])c(F)no1
# Starting conversion
# Conversion for Smiles [H]N=c1nc([H])c(F)no1 finished
# Converting Smiles: [H]OC1([H])C(=O)C2([H])C([H])(C([H])([H])[H])C12[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C(=O)C2([H])C([H])(C([H])([H])[H])C12[H] finished
# Converting Smiles: [H]C1([H])OC(=O)C2(OC2([H])[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])OC(=O)C2(OC2([H])[H])C1([H])[H] finished
# Converting Smiles: [H]C#CC1([H])C([H])([H])OC([H])([H])C1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC1([H])C([H])([H])OC([H])([H])C1([H])C([H])([H])[H] finished
# Converting Smiles: [H]C([H])([H])C1(C2([H])C([H])([H])OC2([H])[H])OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1(C2([H])C([H])([H])OC2([H])[H])OC1([H])[H] finished
# Converting Smiles: [H]C#CC1(O[H])C([H])([H])C([H])(C([H])([H])[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC1(O[H])C([H])([H])C([H])(C([H])([H])[H])C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])C1([H])OC2([H])C([H])([H])N3C1([H])C32[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1([H])OC2([H])C([H])([H])N3C1([H])C32[H] finished
# Converting Smiles: [H]C(=O)C1=C([H])C([H])([H])C(=O)C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C1=C([H])C([H])([H])C(=O)C1([H])[H] finished
# Converting Smiles: [H]OC1([H])C([H])(C([H])([H])[H])N2C([H])([H])C21C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])(C([H])([H])[H])N2C([H])([H])C21C([H])([H])[H] finished
# Converting Smiles: [H]N1C(=O)C2([H])OC2([H])C1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N1C(=O)C2([H])OC2([H])C1([H])C([H])([H])[H] finished
# Converting Smiles: [H]C([H])([H])C12C([H])([H])C1([H])C1([H])C([H])([H])C2([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C12C([H])([H])C1([H])C1([H])C([H])([H])C2([H])C1([H])[H] finished
# Converting Smiles: [H]C1([H])OC1(C#N)C1([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])OC1(C#N)C1([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])Oc1nnoc1C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])Oc1nnoc1C([H])([H])[H] finished
# Converting Smiles: [H]N1C([H])([H])C1([H])C1([H])C(=O)OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]N1C([H])([H])C1([H])C1([H])C(=O)OC1([H])[H] finished
# Converting Smiles: [H]c1noc(C([H])([H])C([H])([H])[H])c1C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]c1noc(C([H])([H])C([H])([H])[H])c1C([H])([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C12C([H])([H])C(=O)C1([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C12C([H])([H])C(=O)C1([H])C2([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C1(O[H])C(=O)N([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1(O[H])C(=O)N([H])C1([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C1(C2([H])N([H])C2([H])[H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1(C2([H])N([H])C2([H])[H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]C([H])(C#N)N1C([H])([H])C([H])([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])(C#N)N1C([H])([H])C([H])([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C1([H])N=C([H])N([H])C1=O
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1([H])N=C([H])N([H])C1=O finished
# Converting Smiles: [H]C1=NC([H])([H])C(=O)N1C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=NC([H])([H])C(=O)N1C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]C#CC1(C([H])(C([H])([H])[H])C([H])([H])[H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC1(C([H])(C([H])([H])[H])C([H])([H])[H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]N=C1OC([H])([H])C([H])([H])N([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]N=C1OC([H])([H])C([H])([H])N([H])C1([H])[H] finished
# Converting Smiles: [H]OC1(C([H])=O)C([H])([H])OC([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1(C([H])=O)C([H])([H])OC([H])([H])C1([H])[H] finished
# Converting Smiles: [H]ON=C1C([H])(C([H])([H])[H])OC1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]ON=C1C([H])(C([H])([H])[H])OC1([H])C([H])([H])[H] finished
# Converting Smiles: [H]OC1([H])C([H])([H])C2(C([H])([H])C([H])([H])[H])C([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])([H])C2(C([H])([H])C([H])([H])[H])C([H])([H])C12[H] finished
# Converting Smiles: [H]c1nc([H])n([H])c(=O)c1F
# Starting conversion
# Conversion for Smiles [H]c1nc([H])n([H])c(=O)c1F finished
# Converting Smiles: [H]OC([H])([H])C1([H])C([H])([H])C1([H])N1C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1([H])C([H])([H])C1([H])N1C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C1([H])C2([H])C([H])([H])C([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1([H])C2([H])C([H])([H])C([H])([H])C12[H] finished
# Converting Smiles: [H]OC1([H])C([H])([H])C([H])(C([H])([H])[H])C12C([H])([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])([H])C([H])(C([H])([H])[H])C12C([H])([H])C2([H])[H] finished
# Converting Smiles: [H]C#CC([H])([H])C([H])([H])C([H])(C([H])([H])[H])C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC([H])([H])C([H])([H])C([H])(C([H])([H])[H])C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]C(=O)C([H])([H])OC1([H])C([H])([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C([H])([H])OC1([H])C([H])([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]OC1([H])C([H])=C([H])C([H])(O[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])=C([H])C([H])(O[H])C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])C([H])([H])N1C([H])([H])C1(C#N)C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C([H])([H])N1C([H])([H])C1(C#N)C([H])([H])[H] finished
# Converting Smiles: [H]c1nc(OC([H])([H])C([H])([H])[H])c([H])n1[H]
# Starting conversion
# Conversion for Smiles [H]c1nc(OC([H])([H])C([H])([H])[H])c([H])n1[H] finished
# Converting Smiles: [H]C1([H])OC([H])([H])C([H])([H])C([H])([H])OC([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])OC([H])([H])C([H])([H])C([H])([H])OC([H])([H])C1([H])[H] finished
# Converting Smiles: [H]c1nnoc1N([H])C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]c1nnoc1N([H])C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]C(=O)c1onc([H])c1N([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)c1onc([H])c1N([H])[H] finished
# Converting Smiles: [H]C(=O)c1nc([H])c([H])c([H])c1[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)c1nc([H])c([H])c([H])c1[H] finished
# Converting Smiles: [H]N([H])C([H])([H])C([H])(C#N)N([H])[H]
# Starting conversion
# Conversion for Smiles [H]N([H])C([H])([H])C([H])(C#N)N([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C1=C([H])C([H])([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1=C([H])C([H])([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]c1nc(C([H])([H])[H])c(=O)n([H])n1
# Starting conversion
# Conversion for Smiles [H]c1nc(C([H])([H])[H])c(=O)n([H])n1 finished
# Converting Smiles: [H]c1nn([H])nc1C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]c1nn([H])nc1C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]C([H])([H])C(=O)C([H])([H])C([H])([H])C1([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C(=O)C([H])([H])C([H])([H])C1([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])N1C2([H])C(=O)OC([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])N1C2([H])C(=O)OC([H])([H])C12[H] finished
# ...
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1([H])OC([H])([H])C1([H])C([H])([H])O[H] finished
# Converting Smiles: [H]C([H])([H])C1([H])OC(=O)C([H])(C([H])([H])[H])O1
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1([H])OC(=O)C([H])(C([H])([H])[H])O1 finished
# Converting Smiles: [H]N1C(=O)C2([H])OC([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]N1C(=O)C2([H])OC([H])([H])C12[H] finished
# Converting Smiles: [H]C(=O)C#CC([H])([H])C#N
# Starting conversion
# Conversion for Smiles [H]C(=O)C#CC([H])([H])C#N finished
# Converting Smiles: [H]C(=O)N1C2([H])C([H])([H])C([H])([H])C([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)N1C2([H])C([H])([H])C([H])([H])C([H])([H])C12[H] finished
# Converting Smiles: [H]c1nc([H])c(=O)n([H])c1C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]c1nc([H])c(=O)n([H])c1C([H])([H])[H] finished
# Converting Smiles: [H]N1C2([H])C1([H])C1(C([H])([H])[H])C([H])([H])C([H])([H])C21[H]
# Starting conversion
# Conversion for Smiles [H]N1C2([H])C1([H])C1(C([H])([H])[H])C([H])([H])C([H])([H])C21[H] finished
# Converting Smiles: [H]OC([H])(C#CC([H])([H])[H])C([H])([H])C([H])=O
# Starting conversion
# Conversion for Smiles [H]OC([H])(C#CC([H])([H])[H])C([H])([H])C([H])=O finished
# Converting Smiles: [H]C(=O)C#CC1([H])C([H])([H])OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C#CC1([H])C([H])([H])OC1([H])[H] finished
# Converting Smiles: [H]c1nc(N([H])C([H])([H])[H])n([H])n1
# Starting conversion
# Conversion for Smiles [H]c1nc(N([H])C([H])([H])[H])n([H])n1 finished
# Converting Smiles: [H]C#CC12C([H])=C([H])C([H])([H])N1C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC12C([H])=C([H])C([H])([H])N1C2([H])[H] finished
# Converting Smiles: [H]C#CC(C([H])([H])[H])(C([H])([H])[H])C([H])([H])C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC(C([H])([H])[H])(C([H])([H])[H])C([H])([H])C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]C1=C([H])C([H])([H])C2(C([H])([H])C1([H])[H])C([H])([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C([H])([H])C2(C([H])([H])C1([H])[H])C([H])([H])C2([H])[H] finished
# Converting Smiles: [H]C([H])([H])C([H])([H])C([H])([H])C1([H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C([H])([H])C([H])([H])C1([H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]N1C(=O)C2(N(C([H])([H])[H])C2([H])[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]N1C(=O)C2(N(C([H])([H])[H])C2([H])[H])C1([H])[H] finished
# Converting Smiles: [H]C#CC([H])([H])c1oc([H])c([H])c1[H]
# Starting conversion
# Conversion for Smiles [H]C#CC([H])([H])c1oc([H])c([H])c1[H] finished
# Converting Smiles: [H]OC1(C2([H])OC2([H])[H])C([H])([H])C1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1(C2([H])OC2([H])[H])C([H])([H])C1([H])C([H])([H])[H] finished
# Converting Smiles: [H]C1=C([H])C2([H])C([H])([H])C(=O)C1([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C2([H])C([H])([H])C(=O)C1([H])C2([H])[H] finished
# Converting Smiles: [H]C1([H])C([H])([H])C([H])([H])C2([H])C([H])([H])C([H])([H])C2([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])C([H])([H])C([H])([H])C2([H])C([H])([H])C([H])([H])C2([H])C1([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C12N([H])C3([H])C1([H])N([H])C32[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C12N([H])C3([H])C1([H])N([H])C32[H] finished
# Converting Smiles: [H]OC([H])([H])C1=C([H])C([H])([H])C2([H])OC12[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1=C([H])C([H])([H])C2([H])OC12[H] finished
# Converting Smiles: [H]C#CC([H])(C([H])([H])[H])C([H])([H])C([H])([H])OC([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC([H])(C([H])([H])[H])C([H])([H])C([H])([H])OC([H])([H])[H] finished
# Converting Smiles: [H]Oc1c([H])c([H])c(C([H])([H])C([H])([H])[H])n1[H]
# Starting conversion
# Conversion for Smiles [H]Oc1c([H])c([H])c(C([H])([H])C([H])([H])[H])n1[H] finished
# Converting Smiles: [H]C1=C([H])C2(N([H])C2([H])[H])C([H])([H])C1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C2(N([H])C2([H])[H])C([H])([H])C1([H])C([H])([H])[H] finished
# Converting Smiles: [H]C([H])([H])C1([H])C2([H])C([H])([H])C3(C([H])([H])C3([H])[H])C12[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1([H])C2([H])C([H])([H])C3(C([H])([H])C3([H])[H])C12[H] finished
# Converting Smiles: [H]C1=NC2(C([H])([H])[H])C([H])([H])C2([H])O1
# Starting conversion
# Conversion for Smiles [H]C1=NC2(C([H])([H])[H])C([H])([H])C2([H])O1 finished
# Converting Smiles: [H]OC([H])([H])C([H])(O[H])C(=O)OC([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C([H])(O[H])C(=O)OC([H])([H])[H] finished
# Converting Smiles: [H]c1onnc1C(=O)C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]c1onnc1C(=O)C([H])([H])[H] finished
# Converting Smiles: [H]C#CC([H])([H])N=C1OC([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC([H])([H])N=C1OC([H])([H])C1([H])[H] finished
# Converting Smiles: [H]N1C([H])([H])C12C([H])([H])C1(OC1([H])[H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]N1C([H])([H])C12C([H])([H])C1(OC1([H])[H])C2([H])[H] finished
# Converting Smiles: [H]C1=C([H])C2([H])N(C(=O)C2([H])[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C2([H])N(C(=O)C2([H])[H])C1([H])[H] finished
# Converting Smiles: [H]N=c1c([H])c([H])oc(O[H])c1[H]
# Starting conversion
# Conversion for Smiles [H]N=c1c([H])c([H])oc(O[H])c1[H] finished
# Converting Smiles: [H]C#CC([H])([H])C([H])(OC([H])([H])C([H])([H])[H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC([H])([H])C([H])(OC([H])([H])C([H])([H])[H])C([H])([H])[H] finished
# Converting Smiles: [H]C1([H])C(=O)C2(C([H])([H])C([H])([H])[H])N1C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1([H])C(=O)C2(C([H])([H])C([H])([H])[H])N1C2([H])[H] finished
# Converting Smiles: [H]C([H])([H])C12C([H])([H])OC3([H])C1([H])C([H])([H])C32[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C12C([H])([H])OC3([H])C1([H])C([H])([H])C32[H] finished
# Converting Smiles: [H]OC([H])([H])C1(C([H])=O)OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1(C([H])=O)OC1([H])[H] finished
# Converting Smiles: [H]C#CC1([H])C([H])([H])C(C([H])([H])[H])(C([H])([H])[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC1([H])C([H])([H])C(C([H])([H])[H])(C([H])([H])[H])C1([H])[H] finished
# Converting Smiles: [H]N([H])C(=O)C([H])([H])C#CC([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N([H])C(=O)C([H])([H])C#CC([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]OC([H])([H])c1nn([H])c(=O)n1[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])c1nn([H])c(=O)n1[H] finished
# Converting Smiles: [H]C([H])([H])C12C([H])([H])C([H])([H])C1([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C12C([H])([H])C([H])([H])C1([H])C2([H])[H] finished
# Converting Smiles: [H]C#CC([H])([H])c1c([H])c([H])c([H])n1[H]
# Starting conversion
# Conversion for Smiles [H]C#CC([H])([H])c1c([H])c([H])c([H])n1[H] finished
# Converting Smiles: [H]N([H])C(=O)C([H])(C([H])([H])C([H])([H])[H])C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N([H])C(=O)C([H])(C([H])([H])C([H])([H])[H])C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]c1oc(C([H])([H])[H])c([H])c1C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]c1oc(C([H])([H])[H])c([H])c1C([H])([H])[H] finished
# Converting Smiles: [H]N(C(=O)C([H])([H])C(=O)C([H])([H])[H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N(C(=O)C([H])([H])C(=O)C([H])([H])[H])C([H])([H])[H] finished
# Converting Smiles: [H]C#CC1([H])OC1([H])C#C[H]
# Starting conversion
# Conversion for Smiles [H]C#CC1([H])OC1([H])C#C[H] finished
# Converting Smiles: [H]OC1([H])C([H])([H])C([H])([H])C([H])([H])C12C([H])([H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])([H])C([H])([H])C([H])([H])C12C([H])([H])C2([H])[H] finished
# Converting Smiles: [H]C#CC1([H])OC(=N[H])C1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC1([H])OC(=N[H])C1([H])C([H])([H])[H] finished
# Converting Smiles: [H]N=c1c([H])c(N([H])[H])c([H])nn1[H]
# Starting conversion
# Conversion for Smiles [H]N=c1c([H])c(N([H])[H])c([H])nn1[H] finished
# Converting Smiles: [H]C#CC(=NC([H])([H])C#N)N([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC(=NC([H])([H])C#N)N([H])[H] finished
# Converting Smiles: [H]N([H])C(=O)C1(C([H])([H])C([H])([H])[H])OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]N([H])C(=O)C1(C([H])([H])C([H])([H])[H])OC1([H])[H] finished
# Converting Smiles: [H]C1=C(C([H])([H])[H])C2([H])OC1([H])C2=O
# Starting conversion
# Conversion for Smiles [H]C1=C(C([H])([H])[H])C2([H])OC1([H])C2=O finished
# Converting Smiles: [H]C([H])([H])c1nc(C([H])([H])C([H])([H])[H])no1
# Starting conversion
# Conversion for Smiles [H]C([H])([H])c1nc(C([H])([H])C([H])([H])[H])no1 finished
# Converting Smiles: [H]Oc1c(O[H])c(C([H])([H])[H])n([H])c1[H]
# Starting conversion
# Conversion for Smiles [H]Oc1c(O[H])c(C([H])([H])[H])n([H])c1[H] finished
# Converting Smiles: [H]OC([H])([H])C([H])(O[H])C(=O)N([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C([H])(O[H])C(=O)N([H])[H] finished
# Converting Smiles: [H]c1c(C#N)c(N([H])[H])nn1[H]
# Starting conversion
# Conversion for Smiles [H]c1c(C#N)c(N([H])[H])nn1[H] finished
# Converting Smiles: [H]N1C(=O)C2([H])C3([H])C([H])([H])C12C3([H])[H]
# Starting conversion
# Conversion for Smiles [H]N1C(=O)C2([H])C3([H])C([H])([H])C12C3([H])[H] finished
# Converting Smiles: [H]Oc1c([H])c([H])n(C([H])([H])[H])c1[H]
# Starting conversion
# Conversion for Smiles [H]Oc1c([H])c([H])n(C([H])([H])[H])c1[H] finished
# Converting Smiles: [H]OC1(C([H])([H])[H])C([H])(C([H])=O)C1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1(C([H])([H])[H])C([H])(C([H])=O)C1([H])C([H])([H])[H] finished
# Converting Smiles: [H]C(=O)C([H])([H])OC([H])(C([H])([H])[H])C([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C([H])([H])OC([H])(C([H])([H])[H])C([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]OC1([H])C([H])(C([H])([H])[H])C([H])([H])C2([H])C([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])(C([H])([H])[H])C([H])([H])C2([H])C([H])([H])C12[H] finished
# Converting Smiles: [H]OC1([H])C([H])([H])C1([H])OC(=O)N([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])([H])C1([H])OC(=O)N([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C(=O)OC([H])([H])C([H])=O
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C(=O)OC([H])([H])C([H])=O finished
# Converting Smiles: [H]N=C1C(=O)C([H])=C([H])N1C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N=C1C(=O)C([H])=C([H])N1C([H])([H])[H] finished
# Converting Smiles: [H]C(=O)c1nc(N([H])[H])c([H])o1
# Starting conversion
# Conversion for Smiles [H]C(=O)c1nc(N([H])[H])c([H])o1 finished
# Converting Smiles: [H]C([H])([H])C(=O)OC([H])([H])C(=O)C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C(=O)OC([H])([H])C(=O)C([H])([H])[H] finished
# Converting Smiles: [H]N([H])C(=O)N([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N([H])C(=O)N([H])C([H])([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C(=O)C([H])([H])C#N
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C(=O)C([H])([H])C#N finished
# Converting Smiles: [H]C1=C([H])C2([H])C([H])([H])C([H])([H])C2([H])C1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C2([H])C([H])([H])C([H])([H])C2([H])C1([H])C([H])([H])[H] finished
# Converting Smiles: [H]c1c([H])c(C#CC([H])([H])[H])n([H])c1[H]
# Starting conversion
# Conversion for Smiles [H]c1c([H])c(C#CC([H])([H])[H])n([H])c1[H] finished
# Converting Smiles: [H]OC([H])([H])C([H])([H])C([H])([H])C#CC([H])=O
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C([H])([H])C([H])([H])C#CC([H])=O finished
# Converting Smiles: [H]C#CC1([H])C([H])([H])C1([H])OC([H])([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C#CC1([H])C([H])([H])C1([H])OC([H])([H])C([H])([H])[H] finished
# Converting Smiles: [H]N=c1nc([H])onc1N([H])[H]
# Starting conversion
# Conversion for Smiles [H]N=c1nc([H])onc1N([H])[H] finished
# Converting Smiles: [H]C(=O)C12N([H])C1([H])C([H])([H])C2([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C12N([H])C1([H])C([H])([H])C2([H])C([H])([H])[H] finished
# Converting Smiles: [H]N=C1OC([H])([H])C([H])([H])C([H])(O[H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]N=C1OC([H])([H])C([H])([H])C([H])(O[H])C1([H])[H] finished
# Converting Smiles: [H]Oc1nc([H])nn1C([H])=O
# Starting conversion
# Conversion for Smiles [H]Oc1nc([H])nn1C([H])=O finished
# Converting Smiles: [H]c1nc(F)nc(C([H])([H])[H])n1
# Starting conversion
# Conversion for Smiles [H]c1nc(F)nc(C([H])([H])[H])n1 finished
# Converting Smiles: [H]OC([H])(C(=O)N([H])[H])C([H])([H])OC([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])(C(=O)N([H])[H])C([H])([H])OC([H])([H])[H] finished
# Converting Smiles: [H]C(=O)C([H])([H])C1([H])C([H])([H])C2([H])C([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C([H])([H])C1([H])C([H])([H])C2([H])C([H])([H])C12[H] finished
# Converting Smiles: [H]C#CC([H])([H])C([H])([H])C([H])([H])N([H])C([H])=O
# Starting conversion
# Conversion for Smiles [H]C#CC([H])([H])C([H])([H])C([H])([H])N([H])C([H])=O finished
# Converting Smiles: [H]N=C(OC([H])([H])C([H])([H])[H])C([H])([H])OC([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N=C(OC([H])([H])C([H])([H])[H])C([H])([H])OC([H])([H])[H] finished
# Converting Smiles: [H]OC1([H])C([H])([H])C([H])=C2C([H])([H])OC21[H]
# Starting conversion
# Conversion for Smiles [H]OC1([H])C([H])([H])C([H])=C2C([H])([H])OC21[H] finished
# Converting Smiles: [H]c1nc(C([H])([H])[H])c(C([H])([H])[H])nc1[H]
# Starting conversion
# Conversion for Smiles [H]c1nc(C([H])([H])[H])c(C([H])([H])[H])nc1[H] finished
# Converting Smiles: [H]N=C1OC([H])([H])OC([H])([H])C1=O
# Starting conversion
# Conversion for Smiles [H]N=C1OC([H])([H])OC([H])([H])C1=O finished
# Converting Smiles: [H]N=C([H])Oc1oc([H])c([H])c1[H]
# Starting conversion
# Conversion for Smiles [H]N=C([H])Oc1oc([H])c([H])c1[H] finished
# Converting Smiles: [H]C1=C([H])C(C([H])([H])[H])(C([H])([H])C([H])([H])[H])C([H])([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C(C([H])([H])[H])(C([H])([H])C([H])([H])[H])C([H])([H])C1([H])[H] finished
# Converting Smiles: [H]C1=C([H])C2([H])C([H])([H])C1([H])C1([H])C([H])([H])C21[H]
# Starting conversion
# Conversion for Smiles [H]C1=C([H])C2([H])C([H])([H])C1([H])C1([H])C([H])([H])C21[H] finished
# Converting Smiles: [H]C([H])([H])C([H])([H])C([H])(C#N)C1([H])OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C([H])([H])C([H])(C#N)C1([H])OC1([H])[H] finished
# Converting Smiles: [H]N([H])C(=O)N1C([H])([H])C([H])([H])C1([H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H]N([H])C(=O)N1C([H])([H])C([H])([H])C1([H])C([H])([H])[H] finished
# Converting Smiles: [H]OC([H])([H])C1([H])OC2([H])C([H])([H])C12[H]
# Starting conversion
# Conversion for Smiles [H]OC([H])([H])C1([H])OC2([H])C([H])([H])C12[H] finished
# Converting Smiles: [H]C([H])([H])C1(C2(C([H])([H])[H])C([H])([H])C2([H])[H])OC1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C1(C2(C([H])([H])[H])C([H])([H])C2([H])[H])OC1([H])[H] finished
# Converting Smiles: [H]C(=O)C1([H])OC(=O)N([H])C1([H])[H]
# Starting conversion
# Conversion for Smiles [H]C(=O)C1([H])OC(=O)N([H])C1([H])[H] finished
# Converting Smiles: [H]C([H])([H])C([H])([H])C12OC([H])([H])C([H])(C1([H])[H])C2([H])[H]
# Starting conversion
# Conversion for Smiles [H]C([H])([H])C([H])([H])C12OC([H])([H])C([H])(C1([H])[H])C2([H])[H] finished
# Converting Smiles: [H][N+]([H])=C(C(=O)[O-])N(C([H])([H])[H])C([H])([H])[H]
# Starting conversion
# Conversion for Smiles [H][N+]([H])=C(C(=O)[O-])N(C([H])([H])[H])C([H])([H])[H] finished
# Completed the conversion to .xyz-files.
# Indices of molecules with failed conversion:
# []

# %% [markdown]
# ## Extracting min/max number of none-Hydrogen atoms and the unique atomic species inside the QM8 subset.

# %%
xyz_path = './data_files/subset_xyz_qm8/'
xyz_files = [f for f in os.listdir(xyz_path) if f.endswith('.xyz')]


# Getting the maximum and minimum number of atoms over all molecules inside the QM8 subset
all_molecules = []
for xyz in xyz_files:
    file_path = os.path.join(xyz_path, xyz)
    try:
        xyz_mol = read(file_path)
        if xyz_mol is not None:
            all_molecules.append(xyz_mol)
    except Exception as e:
        print(f"Molecule {xyz} could not be read properly: {e}")

value_n_atoms_max = np.max([mol.get_global_number_of_atoms() for mol in all_molecules])
value_n_atoms_min = np.min([mol.get_global_number_of_atoms() for mol in all_molecules])
print(f'Maximum ({value_n_atoms_max}) and minimum ({value_n_atoms_min}) number of atoms in the QM8 subset.')


# Getting the unique atomic species from the QM8 subset
unique_atoms = set('H',)
for smi in df_id_col['smiles']:
    mol = Chem.MolFromSmiles(smi)
    if mol is None:
        print(f"WARNING: could not parse SMILES {smi}")
        continue
    for atom in mol.GetAtoms():
        unique_atoms.add(atom.GetSymbol())

print("Unique atomic species found:", unique_atoms)
# Out:
# Maximum (26) and minimum (5) number of atoms in the QM8 subset.
# Unique atomic species found: {'O', 'F', 'C', 'N', 'H'}
